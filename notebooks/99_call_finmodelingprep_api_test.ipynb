# %%
import os

path_parent = os.path.dirname(os.getcwd())
os.chdir(path_parent)

# %%
from urllib.request import urlopen
import json
import numpy as np
import pandas as pd
from datetime import datetime
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm

# %%
from utils.fetch_data_fmp import FMP

# %% [markdown]
# #### Auth

# %%
with open('keys/keys.json', 'r') as key_file:
    keys = json.load(key_file)
    
fmp = FMP(keys['financial_modeling_prep'])
# Out:
# 2023-06-23 15:16:08,111 [utils.fetch_data_fmp] [INFO] Financial Modeling Prep api ready.

# %%
sector_performance = fmp.get_sector_preformance(start_date='2020-01-01', end_date='2023-05-31')
sector_performance.head()
# Out:
#          date  utilitiesChangesPercentage  basicMaterialsChangesPercentage  \
# 0  2023-06-23                     2.67679                          1.55208
# 1  2023-06-22                     2.67679                          1.55208
# 2  2023-06-21                     1.05372                          0.35041
# 3  2023-06-20                    -0.12375                         -0.34483
# 4  2023-06-19                     0.01441                          1.59459
#
#    communicationServicesChangesPercentage conglomeratesChangesPercentage  \
# 0                                 2.25711                           None
# 1                                 2.25711                           None
# 2                                -0.49203                           None
# 3                                -0.05355                           None
# 4                                -0.34363                           None
#
#    consumerCyclicalChangesPercentage  consumerDefensiveChangesPercentage  \
# ...

# %%
apple = fmp.get_historical_daily_price('stock', "AAPL", '2020-01-01', '2023-50-31')
apple.head()
# Out:
#         date    open     high       low   close    adjClose     volume  \
# 0 2023-06-22  183.74  187.045  183.6700  187.00  187.000000   50825877
# 1 2023-06-21  184.90  185.410  182.5901  183.96  183.960007   49515697
# 2 2023-06-20  184.41  186.100  184.4100  185.01  185.009995   49799092
# 3 2023-06-16  186.73  186.990  184.2700  184.92  184.919998  101151225
# 4 2023-06-15  183.96  186.520  183.7800  186.01  186.009995   65433166
#
#    unadjustedVolume  change  changePercent    vwap        label  \
# 0          50747851    3.26        1.77000  186.11  June 22, 23
# 1          49515700   -0.94       -0.50838  184.08  June 21, 23
# 2          49799100    0.60        0.32536  185.27  June 20, 23
# 3         101235600   -1.81       -0.96931  185.46  June 16, 23
# 4          65433200    2.05        1.11000  185.57  June 15, 23
#
#    changeOverTime symbol
# 0        0.017700   AAPL
# 1       -0.005084   AAPL
# 2        0.003254   AAPL
# 3       -0.009693   AAPL
# ...
